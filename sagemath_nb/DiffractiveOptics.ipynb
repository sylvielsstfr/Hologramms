# %% [markdown]
# ## Tache de Airy pour une ouverture rectangulaire

# %%
f = "(sin(x)/x)^2*(sin(y)/y)^2"

# %%
opts = "[plot_format, openmath]"

# %%
maxima.plot3d (f, "[x, -5, 5]", "[y, -5, 5]", opts)

# %% [markdown]
# ## Bessel

# %%
opts="[figsize=(3,3)]"

# %%
plot(bessel_J(0, x),(x, 1, 10),figsize=(3,3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
complex_plot(bessel_Y(0, x), (-5, 5), (-5, 5), plot_points=50,figsize=(3,3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
y = function('y')(x)
a, b = var('a, b')

# %%
diffeq = x^2*diff(y,x,x) + x*diff(y,x) + x^2*y == 0

# %%
f = desolve(diffeq, y, [1, a, b])

# %%
latex(f)
# Out:
# \frac{{\left(a Y_{1}(1) + b Y_{0}(1)\right)} J_{0}(x)}{J_{0}(1) Y_{1}(1) - J_{1}(1) Y_{0}(1)} - \frac{{\left(a J_{1}(1) + b J_{0}(1)\right)} Y_{0}(x)}{J_{0}(1) Y_{1}(1) - J_{1}(1) Y_{0}(1)}

# %%
plot([ Bessel(i, 'J') for i in range(5) ], 2, 10,figsize=(4,4))
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
G = Graphics()
G += sum([ plot(Bessel(i), 0, 4*pi, rgbcolor=hue(sin(pi*i/10))) for i in range(5) ])
show(G,figsize=(4,4))
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
G  = plot(Bessel(0, 'J'), 0, 15, color='black')
G += plot(Bessel(0, 'Y'), 0, 15, color='black')
G += plot(Bessel(1, 'J'), 0, 15, color='black', linestyle='dotted')
G += plot(Bessel(1, 'Y'), 0, 15, color='black', linestyle='dotted')
show(G, ymin=-1, ymax=1,figsize=(4,4))
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
plot(bessel_J(1,x), (x,0,5), color='blue',figsize=(4,4))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
complex_plot(bessel_J(1, x), (-5, 5), (-5, 5), plot_points=20,figsize=(4,4))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(bessel_K(1,x), (x,0,5), color='blue',figsize=(3,3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
complex_plot(bessel_K(1, x), (-5, 5), (-5, 5), plot_points=50,figsize=(3,3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(bessel_Y(1,x), (x,0,5), color='blue',figsize=(3,3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
complex_plot(bessel_Y(1, x), (-5, 5), (-5, 5), plot_points=20,figsize=(3,3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
latex(hankel1(3, x))
# Out:
# H_{3}^{(1)}\left(x\right)

# %%
spherical_bessel_J(3, x);
# Out:
# j_{4}\left(x\right)

# %%
spherical_bessel_J(3 + 0.2 * I, 3)
# Out:
# 0.150770999183897 - 0.0260662466510632*I

# %%
spherical_bessel_J(3, x).series(x == 2, 10).subs(x=3).n()
# Out:
# 0.152051648665037

# %%
spherical_bessel_J(2.,3.)      # rel tol 1e-10
# Out:
# 0.298637497075734

# %%
spherical_bessel_J(4, x).simplify()
# Out:
# -((45/x^2 - 105/x^4 - 1)*sin(x) + 5*(21/x^2 - 2)*cos(x)/x)/x

# %%
integrate(spherical_bessel_J(1,x)^2,(x,0,oo))
# Out:
# 1/6*pi

# %%
latex(spherical_bessel_J(4, x))
# Out:
# j_{4}\left(x\right)
